# %%
import pandas as pd
import numpy as np
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import xgboost as xgb
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from scipy.sparse import hstack, csr_matrix
from sklearn.preprocessing import FunctionTransformer


# Step 1: Load the data
df = pd.read_excel('Participants_Data_News_category/Data_Train.xlsx')

# Step 2: Preprocessing functions
nltk.download('wordnet')
def remove_emoji(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

def pre_process(text):
    text = [char for char in text if char not in string.punctuation]
    text = ''.join(text)
    text = re.sub('[0-9]', '', text)
    no_stop = [word for word in text.split() if word not in stopwords.words('english')]
    no_stop = ' '.join(no_stop)
    lemmatizer = WordNetLemmatizer()
    word_tokens = word_tokenize(no_stop)
    fin_txt = ' '.join([lemmatizer.lemmatize(word) for word in word_tokens])
    return fin_txt

# Step 3: Create pipeline
pipeline = Pipeline([
    ('preprocess', CountVectorizer(analyzer=pre_process)),
    ('tfidf', TfidfTransformer()),
    ('feature_union', FunctionTransformer(lambda X: X)),
    ('classifier', xgb.XGBClassifier())
])

# Step 4: Split the data into train and test sets
X = df['STORY']
y = df['SECTION']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 5: Fit the pipeline on training data
pipeline.fit(X_train, y_train)

# Step 6: Make predictions on test data
predict = pipeline.predict(X_test)

# Step 7: Evaluate the model's performance
print(accuracy_score(y_test, predict))
print(classification_report(y_test, predict))
print(confusion_matrix(y_test, predict))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 0.7986020096111839
#               precision    recall  f1-score   support
#
#            0       0.82      0.76      0.79       491
#            1       0.78      0.86      0.82       846
#            2       0.85      0.85      0.85       598
#            3       0.72      0.64      0.67       354
#
#     accuracy                           0.80      2289
#    macro avg       0.79      0.77      0.78      2289
# weighted avg       0.80      0.80      0.80      2289
#
# [[373  65  26  27]
#  [ 32 724  45  45]
#  [ 22  53 506  17]
#  [ 28  82  19 225]]

# %%
# !pip install --upgrade xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-1.7.6-py3-none-win_amd64.whl (70.9 MB)
#      ---------------------------------------- 70.9/70.9 MB 1.5 MB/s eta 0:00:00
# Collecting numpy
#   Downloading numpy-1.25.0-cp310-cp310-win_amd64.whl (15.0 MB)
#      ---------------------------------------- 15.0/15.0 MB 2.2 MB/s eta 0:00:00
# Collecting scipy
#   Downloading scipy-1.11.1-cp310-cp310-win_amd64.whl (44.0 MB)
#      ---------------------------------------- 44.0/44.0 MB 2.2 MB/s eta 0:00:00
# Installing collected packages: numpy, scipy, xgboost
# Successfully installed numpy-1.25.0 scipy-1.11.1 xgboost-1.7.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# vaex-core 4.16.1 requires aplus, which is not installed.
# vaex-core 4.16.1 requires blake3, which is not installed.
# vaex-core 4.16.1 requires cloudpickle, which is not installed.
# vaex-core 4.16.1 requires dask!=2022.4.0, which is not installed.
# vaex-core 4.16.1 requires pandas, which is not installed.
# vaex-core 4.16.1 requires tabulate>=0.8.3, which is not installed.
# vaex-astro 0.9.3 requires astropy, which is not installed.
# ipyvolume 0.6.1 requires ipywebrtc, which is not installed.
# ipyvolume 0.6.1 requires matplotlib, which is not installed.
# ipyvolume 0.6.1 requires traittypes, which is not installed.
# ipympl 0.9.3 requires matplotlib<4,>=3.4.0, which is not installed.
# ipydatawidgets 4.3.3 requires traittypes>=0.2.0, which is not installed.
# bqplot 0.12.39 requires pandas<3.0.0,>=1.0.0, which is not installed.
# bqplot 0.12.39 requires traittypes>=0.0.6, which is not installed.

# %%
import pandas as pd
import numpy as np
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import xgboost as xgb
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from scipy.sparse import hstack, csr_matrix
from sklearn.preprocessing import FunctionTransformer


# Step 1: Load the data
df = pd.read_excel('Participants_Data_News_category/Data_Train.xlsx')

# Step 2: Preprocessing functions
nltk.download('wordnet')
def remove_emoji(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

def pre_process(text):
    text = [char for char in text if char not in string.punctuation]
    text = ''.join(text)
    text = re.sub('[0-9]', '', text)
    no_stop = [word for word in text.split() if word not in stopwords.words('english')]
    no_stop = ' '.join(no_stop)
    lemmatizer = WordNetLemmatizer()
    word_tokens = word_tokenize(no_stop)
    fin_txt = ' '.join([lemmatizer.lemmatize(word) for word in word_tokens])
    return fin_txt

# Step 3: Create pipeline
pipeline = Pipeline([
    ('preprocess', CountVectorizer(analyzer=pre_process)),
    ('tfidf', TfidfTransformer()),
    ('feature_union', FunctionTransformer(lambda X: X)),
    ('classifier', xgb.XGBClassifier())
])

# Step 4: Add custom features to the data
def add_custom_features(X):
    word_length = X.apply(lambda x: len(x.split()))
    text_length = X.apply(len)
    return pd.concat([X, word_length, text_length], axis=1)

# Step 5: Split the data into train and test sets
X = df['STORY']
y = df['SECTION']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 6: Fit the pipeline on training data
pipeline.fit(X_train, y_train)

# Step 7: Add custom features to the training and test sets
X_train = add_custom_features(X_train)
X_test = add_custom_features(X_test)

# Step 8: Fit the pipeline with custom features on training data
pipeline.fit(X_train, y_train)

# Step 9: Make predictions on test data
predict = pipeline.predict(X_test)

# Step 10: Evaluate the model's performance
print(accuracy_score(y_test, predict))
print(classification_report(y_test, predict))
print(confusion_matrix(y_test, predict))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Cell In[5], line 72
#      69 X_test = add_custom_features(X_test)
#      71 # Step 8: Fit the pipeline with custom features on training data
# ---> 72 pipeline.fit(X_train, y_train)
#      74 # Step 9: Make predictions on test data
#      75 predict = pipeline.predict(X_test)
#
# File ~\anaconda3\envs\NLP\Lib\site-packages\sklearn\pipeline.py:405, in Pipeline.fit(self, X, y, **fit_params)
#     403     if self._final_estimator != "passthrough":
#     404         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 405         self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     407 return self
#
# File ~\anaconda3\envs\NLP\Lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~\anaconda3\envs\NLP\Lib\site-packages\xgboost\sklearn.py:1471, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1460     params["num_class"] = self.n_classes_
#    1462 (
#    1463     model,
#    1464     metric,
#    (...)
#    1469     xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1470 )
# -> 1471 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1472     missing=self.missing,
#    1473     X=X,
#    1474     y=y,
#    1475     group=None,
#    1476     qid=None,
#    1477     sample_weight=sample_weight,
#    1478     base_margin=base_margin,
#    1479     feature_weights=feature_weights,
#    1480     eval_set=eval_set,
#    1481     sample_weight_eval_set=sample_weight_eval_set,
#    1482     base_margin_eval_set=base_margin_eval_set,
#    1483     eval_group=None,
#    1484     eval_qid=None,
#    1485     create_dmatrix=self._create_dmatrix,
#    1486     enable_categorical=self.enable_categorical,
#    1487     feature_types=self.feature_types,
#    1488 )
#    1490 self._Booster = train(
#    1491     params,
#    1492     train_dmatrix,
#    (...)
#    1501     callbacks=callbacks,
#    1502 )
#    1504 if not callable(self.objective):
#
# File ~\anaconda3\envs\NLP\Lib\site-packages\xgboost\sklearn.py:448, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, feature_types)
#     428 def _wrap_evaluation_matrices(
#     429     missing: float,
#     430     X: Any,
#    (...)
#     444     feature_types: Optional[FeatureTypes],
#     445 ) -> Tuple[Any, List[Tuple[Any, str]]]:
#     446     """Convert array_like evaluation matrices into DMatrix.  Perform validation on the
#     447     way."""
# --> 448     train_dmatrix = create_dmatrix(
#     449         data=X,
#     450         label=y,
#     451         group=group,
#     452         qid=qid,
#     453         weight=sample_weight,
#     454         base_margin=base_margin,
#     455         feature_weights=feature_weights,
#     456         missing=missing,
#     457         enable_categorical=enable_categorical,
#     458         feature_types=feature_types,
#     459         ref=None,
#     460     )
#     462     n_validation = 0 if eval_set is None else len(eval_set)
#     464     def validate_or_none(meta: Optional[Sequence], name: str) -> Sequence:
#
# File ~\anaconda3\envs\NLP\Lib\site-packages\xgboost\sklearn.py:908, in XGBModel._create_dmatrix(self, ref, **kwargs)
#     906     except TypeError:  # `QuantileDMatrix` supports lesser types than DMatrix
#     907         pass
# --> 908 return DMatrix(**kwargs, nthread=self.n_jobs)
#
# File ~\anaconda3\envs\NLP\Lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~\anaconda3\envs\NLP\Lib\site-packages\xgboost\core.py:754, in DMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical)
#     751 assert handle is not None
#     752 self.handle = handle
# --> 754 self.set_info(
#     755     label=label,
#     756     weight=weight,
#     757     base_margin=base_margin,
#     758     group=group,
#     759     qid=qid,
#     760     label_lower_bound=label_lower_bound,
#     761     label_upper_bound=label_upper_bound,
#     762     feature_weights=feature_weights,
#     763 )
#     765 if feature_names is not None:
#     766     self.feature_names = feature_names
#
# File ~\anaconda3\envs\NLP\Lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~\anaconda3\envs\NLP\Lib\site-packages\xgboost\core.py:819, in DMatrix.set_info(self, label, weight, base_margin, group, qid, label_lower_bound, label_upper_bound, feature_names, feature_types, feature_weights)
#     816 from .data import dispatch_meta_backend
#     818 if label is not None:
# --> 819     self.set_label(label)
#     820 if weight is not None:
#     821     self.set_weight(weight)
#
# File ~\anaconda3\envs\NLP\Lib\site-packages\xgboost\core.py:950, in DMatrix.set_label(self, label)
#     942 """Set label of dmatrix
#     943
#     944 Parameters
#    (...)
#     947     The label information to be set into DMatrix
#     948 """
#     949 from .data import dispatch_meta_backend
# --> 950 dispatch_meta_backend(self, label, 'label', 'float')
#
# File ~\anaconda3\envs\NLP\Lib\site-packages\xgboost\data.py:1121, in dispatch_meta_backend(matrix, data, name, dtype)
#    1119     return
#    1120 if _is_pandas_series(data):
# -> 1121     _meta_from_pandas_series(data, name, dtype, handle)
#    1122     return
#    1123 if _is_dlpack(data):
#
# File ~\anaconda3\envs\NLP\Lib\site-packages\xgboost\data.py:430, in _meta_from_pandas_series(data, name, dtype, handle)
#     428     data = data.to_dense()  # type: ignore
#     429 assert len(data.shape) == 1 or data.shape[1] == 0 or data.shape[1] == 1
# --> 430 _meta_from_numpy(data, name, dtype, handle)
#
# File ~\anaconda3\envs\NLP\Lib\site-packages\xgboost\data.py:1037, in _meta_from_numpy(data, field, dtype, handle)
#    1035     raise ValueError("Masked array is not supported.")
#    1036 interface_str = _array_interface(data)
# -> 1037 _check_call(_LIB.XGDMatrixSetInfoFromInterface(handle, c_str(field), interface_str))
#
# File ~\anaconda3\envs\NLP\Lib\site-packages\xgboost\core.py:279, in _check_call(ret)
#     268 """Check the return value of C API call
#     269
#     270 This function will raise exception when error occurs.
#    (...)
#     276     return value from API calls
#     277 """
#     278 if ret != 0:
# --> 279     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#
# XGBoostError: [15:00:26] C:\Users\dev-admin\croot2\xgboost-split_1675461376218\work\src\data\data.cc:455: Check failed: this->labels.Size() % this->num_row_ == 0 (2 vs. 0) : Incorrect size for labels.
